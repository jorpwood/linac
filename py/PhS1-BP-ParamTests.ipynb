# %%
import numpy as np
import math
from matplotlib import pylab as plt
from ROOT import TTree, TFile, TH2D, TCanvas, TH1F, gROOT
from root_numpy import array2hist, hist2array, fill_hist, tree2array, root2array, list_trees
import pandas as pd
from root_pandas import read_root
import uproot

filenames_g=["/work/jo17631/PhaseSpaces/PhS2_10x10_p1_Elec/output3Vacuum.root",\
"/work/jo17631/PhaseSpaces/PhS2_10x10_p1_Elec/output3Air.root",\
"/work/jo17631/PhaseSpaces/PhS2_10x10_p1_Elec/output3Water.root"]
#"/work/lb8075/PhaseSpaces/PhS1Gamma_tests/output-PhS1_emopt3_Brem100-g1.root",\
#"/work/lb8075/PhaseSpaces/PhS1Gamma_tests/output-PhS1_emopt4_Brem100-g1.root",\
#"/work/lb8075/PhaseSpaces/PhS1Gamma_tests/output-PhS1_emopt3_Brem100_FFp5cut-g1.root"]


data_frame_dict={}

for files_g in filenames_g:
    print(f"{files_g}   \n")
    ur=uproot.pandas.iterate(files_g, "PhaseSpace", ['X','Y','dX','dY','Weight','Ekine'])
    mylist=list(ur)        
    data_frame_dict[files_g]=pd.concat(mylist, ignore_index=True, sort=False  ,copy = False)
# Out:
# Welcome to JupyROOT 6.22/02
# /work/jo17631/PhaseSpaces/PhS2_10x10_p1_Elec/output3Vacuum.root
#
# /work/jo17631/PhaseSpaces/PhS2_10x10_p1_Elec/output3Air.root
#
# /work/jo17631/PhaseSpaces/PhS2_10x10_p1_Elec/output3Water.root

# %%
for files_g in filenames_g:
    print(data_frame_dict[files_g]['Weight'].value_counts())
# Out:
# 0.01    694
# 1.00      1
# Name: Weight, dtype: int64
# 0.01    925
# 1.00      2
# Name: Weight, dtype: int64
# 0.01    244
# 1.00      1
# Name: Weight, dtype: int64

# %%
for files_g in filenames_g:
    print(data_frame_dict[files_g]['X'].count())
# Out:
# 695
# 927
# 245

# %%
for files_g in filenames_g:
    plt.subplots(1,1,figsize=(4,4))
    _=plt.hist2d(data_frame_dict[files_g]['X'],data_frame_dict[files_g]['Y'],bins=(200,200))
#     plt.pause(1)
    plt.show()
#     input("wait")

# %%
for files_g in filenames_g:
    plt.subplots(1,1,figsize=(8,4))
    _=plt.hist2d(data_frame_dict[files_g]['X'],data_frame_dict[files_g]['dX'],bins=(100,100))
    plt.xlim(-80,80)
    plt.ylim(-0.7,0.7)
#     plt.pause(1)
    plt.show()
#     input("wait")

# %%
plt.subplots(1,1,figsize=(10,5))

for files_g in filenames_g:
    if "Brem1-" in files_g:
        _=plt.hist(data_frame_dict[files_g]['Ekine'],weights=data_frame_dict[files_g]['Weight'],histtype='step',bins=(200),label=files_g[-10:-5])
    else:
        _=plt.hist(data_frame_dict[files_g]['Ekine'],weights=data_frame_dict[files_g]['Weight'],histtype='step',bins=(200),label=files_g[-10:-5])

plt.yscale('log')
plt.legend
# plt.xlim(0,5.8)
plt.ylim(10,2000)
plt.show()

# %%
import numpy as np
import math
from matplotlib import pylab as plt
from ROOT import TTree, TFile, TH2D, TCanvas, TH1F, gROOT
from root_numpy import array2hist, hist2array, fill_hist, tree2array, root2array, list_trees
import pandas as pd
from root_pandas import read_root
import uproot

filenames_e=["/work/lb8075/PhaseSpaces/PhS1Elec_tests/output-PhS1_emopt3_Brem1-e_total100.root",\
"/work/lb8075/PhaseSpaces/PhS1Elec_tests/output-PhS1_emopt3_Brem100_Airp9-e_total100.root",\
"/work/lb8075/PhaseSpaces/PhS1Elec_tests/output-PhS1_emopt3_Brem100-e_total100.root",\
"/work/lb8075/PhaseSpaces/PhS1Elec_tests/output-PhS1_emopt4_Brem100-e_total100.root",\
"/work/lb8075/PhaseSpaces/PhS1Elec_tests/output-PhS1_emopt3_Brem100_FFp5cut-e_total100.root"]
data_frame_dict={}

for files_e in filenames_e:
    print(f"{files_e}   \n")
    ur=uproot.pandas.iterate(files_e, "PhaseSpace", ['X','Y','dX','dY','Weight','Ekine'])
    mylist=list(ur)        
    data_frame_dict[files_e]=pd.concat(mylist, ignore_index=True, sort=False  ,copy = False)
# Out:
# /work/lb8075/PhaseSpaces/PhS1Elec_tests/output-PhS1_emopt3_Brem1-e_total100.root
#
# /work/lb8075/PhaseSpaces/PhS1Elec_tests/output-PhS1_emopt3_Brem100_Airp9-e_total100.root
#
# /work/lb8075/PhaseSpaces/PhS1Elec_tests/output-PhS1_emopt3_Brem100-e_total100.root
#
# /work/lb8075/PhaseSpaces/PhS1Elec_tests/output-PhS1_emopt4_Brem100-e_total100.root
#
# /work/lb8075/PhaseSpaces/PhS1Elec_tests/output-PhS1_emopt3_Brem100_FFp5cut-e_total100.root

# %%
plt.subplots(1,1,figsize=(10,6))

for files_e in filenames_e:
    labelname=files_e[52:-16]
    print(labelname)
    _=plt.hist(data_frame_dict[files_e]['Ekine'],weights=data_frame_dict[files_e]['Weight'],histtype='step',bins=(150),label=labelname)

plt.legend()
# plt.xlim(0,6.5)
plt.ylim(10,1000)
plt.yscale('log')
plt.show()
# Out:
# emopt3_Brem1
# emopt3_Brem100_Airp9
# emopt3_Brem100
# emopt4_Brem100
# emopt3_Brem100_FFp5cut
